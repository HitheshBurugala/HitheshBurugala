# %%
#  Importing the necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import  matplotlib.pyplot as plt

data = pd.read_csv('Amazon Sales data.csv')  # reading the data(.csv format) and fitting it in a data frame. 
data     # displaying the data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data.head()  # to display the first 5 rows of the data frame.
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
data.columns # Understanding about data before data cleaning
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
data.shape # Understanding about data (shape) before data cleaning
# Out:
# (100, 14)

# %%
data.size # Understanding about data(total size) before data cleaning
# Out:
# 1400

# %%
data.info() # Understanding about data(about each data type) before data cleaning
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
data.describe()  # This function summarizes key information (only numeric data)about dataframe

# data.describe(include='all')    # This specific function (included = 'all') will inlcude non numeric data type as well, 
                                   # but i dont need this only numerical data is fine.
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
data.isna().sum()

# to check whether it is having any null values in the column and summing up the result.
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
data.dtypes 

#To display the type of data types the dataframe has got.
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
# data transformation is being done from object data type to date time object data type.

data = data.astype({'Ship Date': 'datetime64[ns]','Order Date':'datetime64[ns]'})
# to convert the object data type of ''ship date'' and '' order date '' column to datetime object.

data.head()
# to display the first 5 rows of the data frame after converting the object data column
# into the date time object
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H 2010-05-28  669165933 2010-06-27        9925
# 1        Online              C 2012-08-22  963881480 2012-09-15        2804
# 2       Offline              L 2014-05-02  341417157 2014-05-08        1779
# 3        Online              C 2014-06-20  514321792 2014-07-05        8102
# 4       Offline              L 2013-02-01  115456712 2013-02-06        5062
#
# ...

# %%
data.dtypes 

# after converting  ''order date'' column and ''ship date'' column from object data type to datetime data type.
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
# To check whether we have any null values in the data frame in the form of heat maps

plt.figure(figsize=(5,5)) #generating heatmap using seaborn library 

sns.heatmap(data.isnull())    # dispay the heat map to identify whether there is any null values
                             #There is no any null values present in out data.

# In this case there is no null values so we did not see other colours(other than red).
# Out:
# <Axes: >

# %%
# we will test our data frame by inserting a null value at specific cell.
# After that we will generate the heap map to find out the null values.

#          test = data.iloc[0,12] = np.nan
#          test

# intentionally we are make 0 th row and 12 th column as null to test in the heat map

# %%
# plt.figure(figsize=(5,5))     # This specific cell needs to be run after uncommenting (cell no 136)
                              #  (cell no 136) test = data.iloc[0,12] = np.nan
                              # as this will show the missing NA value in the form of heat map.
                              # but for not we will comment out this cell to avoid printing heat map twice.
# sns.heatmap(data.isnull())

# %%
data.isna().sum()  # to check whether it is having any null values in the column and summing up the result.

# here in the above cell(cell no 152) we intentionally made a cell to null value.
# but again we are replacing that cell with the original existing value to perform data analysis correctly.
# so we are commenting out the present cell  i.e cell no 120.
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
# dropping the null values in the data frames

# result = data.dropna()  # as we dont have any null values in the data frame
# result.head(2)           # so the same data will printed
# Out:
#                               Region  Country  Item Type Mode Of Purchase  \
# 0              Australia and Oceania   Tuvalu  Baby Food          Offline
# 1  Central America and the Caribbean  Grenada     Cereal           Online
#
#   Order Priority Order Date   Order ID shipping date  Total Units sold  \
# 0              H 2010-05-28  669165933    2010-06-27              9925
# 1              C 2012-08-22  963881480    2012-09-15              2804
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      255.28     159.42      2533654.0     1582243     951410.50
# 1      205.70     117.11       576782.8      328376     248406.36

# %%
# Detecting if any value in the specific column is missing 

data_show = data.isna().sum() # it will combine the missing value and print the count.
# data_show2 = data.isna() # it will show in the form of false , which is not that interactive.
data_show
# Out:
# Region              0
# Country             0
# Item Type           0
# Mode Of Purchase    0
# Order Priority      0
# Order Date          0
# Order ID            0
# shipping date       0
# Total Units sold    0
# Unit Price          0
# Unit Cost           0
# Total Revenue       0
# Total Cost          0
# Total Profit        0
# dtype: int64

# %%
# Hanlding the missing values in the data frame.

# data = data.fillna(data.mean())  #filling the NA value with the mean 
# data                             # luckiy we dont have any NA value in the data frame 
                                   # so we are commenting it out this cell.

# %%
data.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
# Data transformation

data['Total Cost'] = data['Total Cost'].astype(int)   # Here we are converting existing float data type                                         
                                                      # of the'' Total Cost ''column into the integer type.

data.head(2) # Here we are using data.head(3) to print the first three rows of the data frame.
              # after converting it into integer format.

# Note : Try to be very consious as python is a case sensitive language.
# we need to enter specific alphabet correctly whether it is 'a' or 'A'.
# Out:
#                               Region  Country  Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H 2010-05-28  669165933 2010-06-27        9925      255.28
# 1              C 2012-08-22  963881480 2012-09-15        2804      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42      2533654.0     1582243     951410.50
# 1     117.11       576782.8      328376     248406.36

# %%
# Before renaming the column of the data frame.
data.head(2)
# Out:
#                               Region  Country  Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H 2010-05-28  669165933 2010-06-27        9925      255.28
# 1              C 2012-08-22  963881480 2012-09-15        2804      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42      2533654.0     1582243     951410.50
# 1     117.11       576782.8      328376     248406.36

# %%
#Renaming the column for more readibilty.
# Here i would like to change the colums of my data frame to give more readibility.

# From '' sales channel  '' -----> to ----->'' mode of purchase ''
# From '' ship date '' ----> to ---->'' shipping date ''.
# From '' Units sold '' -----> to -----> '' Total Units sold ''

# data.rename(columns={'present column name': 'to be changed to column name'})

data.rename(columns={'Sales Channel': 'Mode Of Purchase'}, inplace=True)
data.rename(columns={'Ship Date': 'shipping date'}, inplace=True)
data.rename(columns={'Units Sold': 'Total Units sold'}, inplace=True)
data.head(2)
# Out:
#                               Region  Country  Item Type Mode Of Purchase  \
# 0              Australia and Oceania   Tuvalu  Baby Food          Offline
# 1  Central America and the Caribbean  Grenada     Cereal           Online
#
#   Order Priority Order Date   Order ID shipping date  Total Units sold  \
# 0              H 2010-05-28  669165933    2010-06-27              9925
# 1              C 2012-08-22  963881480    2012-09-15              2804
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      255.28     159.42      2533654.0     1582243     951410.50
# 1      205.70     117.11       576782.8      328376     248406.36

# %%
data.columns # Just to check whether our column names got renmaed or not.
# Out:
# Index(['Region', 'Country', 'Item Type', 'Mode Of Purchase', 'Order Priority',
#        'Order Date', 'Order ID', 'shipping date', 'Total Units sold',
#        'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost',
#        'Total Profit'],
#       dtype='object')
